# %% [markdown]
# ### **1- Import Libares and Read Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles_2021.csv')

# %% [markdown]
# ### **2-Show top 5 Rows In Dataset**

# %%
df.head()

# %% [markdown]
# ### **3-Show Last 5 Row In Dataset**

# %%
df.tail()

# %% [markdown]
# ### **4- Find Shape Of Out Dataset (Number of Rows and Number of Columns)**

# %%
df.shape

# %% [markdown]
# ### **5-Get Information About Out Dataset Like Totel Number of Row and Columns ,Datatype of Each Column And memory Requrimant**

# %%
df.info()

# %% [markdown]
# ### **6-Ckeck duplicated values of Dataset**

# %%
df.duplicated().sum()

# %% [markdown]
# ### **7-Ckeck Null values of Dataset And Drop Them**

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
df.shape

# %% [markdown]
# ### **8-Get Over Statistics About The DataSet**

# %%
df.describe()

# %% [markdown]
# ### **9-which of Type Data in Dataset**

# %%
df['type'].value_counts()

# %%
df['type'].value_counts().plot(kind='bar')

# %% [markdown]
# ### **10- Top 10 Dirctor In Dataset**

# %%
df['director'].value_counts().head(10)

# %%
df['director'].value_counts().head(10).plot(kind='bar')

# %%
df.columns

# %%
df.shape

# %%
df['cast'].nunique()

# %% [markdown]
# ### **11- Top 5 Person in Cast**

# %%
df['cast'].value_counts().head()

# %%
df['cast'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# ### **12-Top 10 country In Dataset**

# %%
df.columns

# %%
df['country'].value_counts().head(10)

# %%
plt.figure(figsize=(20,10))
df['country'].value_counts().head(10).plot(kind='pie')
plt.legend()

# %% [markdown]
# ### **13- Top 10 launch dates In Dataset**

# %%
df.columns

# %%
df['date_added'].value_counts().head(10)

# %%
df['date_added'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# ##### **January 1, 2020 is most launch dates**

# %% [markdown]
# ### **14- Top 10 release year In Dataset**

# %%
df.columns

# %%
df['release_year'].nunique()

# %%
df['release_year'].value_counts().head(10)

# %%
plt.Figure(figsize=(20,10))
df['release_year'].value_counts().head(10).plot(kind='bar')
plt.legend()

# %% [markdown]
# ##### **2017 is most year To release**

# %% [markdown]
# ### **15-Rating In Dataset**

# %%
df.columns

# %%
df['rating'].value_counts().head(5)

# %%
(df['rating'].value_counts(normalize=True)*100).head(5).plot(kind='pie')

# %% [markdown]
# ##### **TV-MA Is More Common In Dataset**

# %% [markdown]
# ### **16- Top 20 Duration IN Dataset**

# %%
df.columns

# %%
df['duration'].value_counts().head(20)

# %% [markdown]
# ##### **Duration < (90 min)  More Common In Dataset**

# %% [markdown]
# ### **17-Relation Between Duration and Rating**

# %%
df.groupby('duration')['rating'].value_counts().head(20)

# %%
df.groupby('duration')['rating'].value_counts().head(20).plot(kind='bar')

# %% [markdown]
# ### **18-More Common In Dataset**

# %%
df['listed_in'].value_counts().head(10)

# %%
df['listed_in'].value_counts().head(10).plot(kind='bar')

# %%
df.columns

# %% [markdown]
# ### **19-Relation Between Duration and Release Year**

# %%
df.groupby('duration')['release_year'].value_counts().head(20)
